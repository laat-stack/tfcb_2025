# %% [markdown]
# # Test TFCB2022_RNA conda environment

# %%
import umap
import scanpy
import harmonypy

print(umap.__spec__)
print(scanpy.__spec__)
print(harmonypy.__spec__)
# Out:
# ModuleSpec(name='umap', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fd476f0b040>, origin='/opt/conda/envs/tfcb2022_rna/lib/python3.9/site-packages/umap/__init__.py', submodule_search_locations=['/opt/conda/envs/tfcb2022_rna/lib/python3.9/site-packages/umap'])
# ModuleSpec(name='scanpy', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fd44a442400>, origin='/opt/conda/envs/tfcb2022_rna/lib/python3.9/site-packages/scanpy/__init__.py', submodule_search_locations=['/opt/conda/envs/tfcb2022_rna/lib/python3.9/site-packages/scanpy'])
# ModuleSpec(name='harmonypy', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fd432e70850>, origin='/opt/conda/envs/tfcb2022_rna/lib/python3.9/site-packages/harmonypy/__init__.py', submodule_search_locations=['/opt/conda/envs/tfcb2022_rna/lib/python3.9/site-packages/harmonypy'])
